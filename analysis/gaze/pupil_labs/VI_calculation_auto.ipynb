# %% [markdown]
# ### Vertical Index calcultation from preprocessed data tables
# In this code we will load the data and calculate the vertical index as
# VI=V-H/V+H
#
# Names of files used in session are the ones used to load the correspoding preprocessed data

# %% [markdown]
# Lets load the data

# %%
import pandas as pd 
import numpy as np
from pathlib import Path
import os
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import signal
import sys
sys.path.append('../../')
import commons as cm
from data_curation import Normalization
from pandasql import sqldf
from pyeyemo.gaze import gaze_commons as gm

from itertools import compress

nm=Normalization()

# %%
session_location = Path(r"P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS")
data_path=Path(r"data")
sessions=[]
df_list=[]

with open('session.txt','r') as f:
    for session in f:
            sessions.append(session.replace('\n',''))
f.close()
session_loc_list=[session_location.joinpath(session,'01 Processing_data','pupil_labs') for session in sessions ]

for subject, recording_location in zip(sessions,session_loc_list):
    #Load data in folders
    recording_folder=[record for record in os.listdir(recording_location)  if '00' in record]
    print(recording_folder)
    index_aux = list(map(lambda x: not('_' in x), recording_folder))
    recording_folder=list(compress(recording_folder,index_aux))
    #Load data in folders
    if len(recording_folder)>1:
        ValueError('Ambiguty in folder of experiment')
    recording_location=recording_location.joinpath(recording_folder[0],'exports')
    recording_location_raw=recording_location.joinpath(recording_folder[0],'exports')
    export_folder=[record for record in os.listdir(recording_location)  if '00' in record]
    if len(export_folder)>1:
        ValueError('Ambiguty in folder of exports')
    recording_location=recording_location.joinpath(export_folder[0])

    annotations_csv = os.path.join(recording_location,'annotations.csv')
    annotations_pd = pd.read_csv(annotations_csv) 
    exported_gaze_csv = data_path.joinpath(subject.replace('_PC_EM',"")+'_saccades.csv') 
    gaze_pd_frame = pd.read_csv(exported_gaze_csv)
    print(f'Analiysing session: {subject}, annotations: {annotations_csv}, gaze: {exported_gaze_csv}')

    ## Compute vertical index for each subject
    vertical_index_df=gm.vertical_index(gaze_pd_frame,annotations_pd)
    vertical_index_df.index=[subject]
    df_list.append(vertical_index_df)
vertical_index_concat_df=pd.concat(df_list)
vertical_index_concat_df.to_csv('vi_table.csv')
# Out:
# ['002']
# Analiysing session: ES0001_S003_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S003_PC_EM\01 Processing_data\pupil_labs\002\exports\002\annotations.csv, gaze: data\ES0001_S003_saccades.csv
# ['005', 'ES0001_S004_Script.txt']
# Analiysing session: ES0001_S004_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S004_PC_EM\01 Processing_data\pupil_labs\005\exports\002\annotations.csv, gaze: data\ES0001_S004_saccades.csv
# ['006', 'ES0001_S005_Script.txt']
# Analiysing session: ES0001_S005_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S005_PC_EM\01 Processing_data\pupil_labs\006\exports\001\annotations.csv, gaze: data\ES0001_S005_saccades.csv
# ['007']
# Analiysing session: ES0001_S006_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S006_PC_EM\01 Processing_data\pupil_labs\007\exports\000\annotations.csv, gaze: data\ES0001_S006_saccades.csv
# ['004', 'ES0001_S008_Script.txt']
# Analiysing session: ES0001_S008_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S008_PC_EM\01 Processing_data\pupil_labs\004\exports\000\annotations.csv, gaze: data\ES0001_S008_saccades.csv
# ['008', 'ES0001_S009_Script.txt']
# Analiysing session: ES0001_S009_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S009_PC_EM\01 Processing_data\pupil_labs\008\exports\001\annotations.csv, gaze: data\ES0001_S009_saccades.csv
# ['009']
# Analiysing session: ES0001_S010_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S010_PC_EM\01 Processing_data\pupil_labs\009\exports\000\annotations.csv, gaze: data\ES0001_S010_saccades.csv
# ['002']
# Analiysing session: ES0001_S011_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S011_PC_EM\01 Processing_data\pupil_labs\002\exports\000\annotations.csv, gaze: data\ES0001_S011_saccades.csv
# ['001']
# Analiysing session: ES0001_S012_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S012_PC_EM\01 Processing_data\pupil_labs\001\exports\000\annotations.csv, gaze: data\ES0001_S012_saccades.csv
# ['006']
# Analiysing session: ES0001_S013_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S013_PC_EM\01 Processing_data\pupil_labs\006\exports\000\annotations.csv, gaze: data\ES0001_S013_saccades.csv
# ['003']
# Analiysing session: ES0001_S015_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S015_PC_EM\01 Processing_data\pupil_labs\003\exports\001\annotations.csv, gaze: data\ES0001_S015_saccades.csv
# ['005', 'ES0001_S017_Script.txt']
# Analiysing session: ES0001_S017_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S017_PC_EM\01 Processing_data\pupil_labs\005\exports\000\annotations.csv, gaze: data\ES0001_S017_saccades.csv
# ['006', 'ES001_S018_Script.txt']
# Analiysing session: ES0001_S018_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S018_PC_EM\01 Processing_data\pupil_labs\006\exports\000\annotations.csv, gaze: data\ES0001_S018_saccades.csv
# ['000', 'ES001_S019_Script.txt']
# Analiysing session: ES0001_S019_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S019_PC_EM\01 Processing_data\pupil_labs\000\exports\001\annotations.csv, gaze: data\ES0001_S019_saccades.csv
# ['001', 'ES0001_S020_Script.txt']
# Analiysing session: ES0001_S020_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S020_PC_EM\01 Processing_data\pupil_labs\001\exports\000\annotations.csv, gaze: data\ES0001_S020_saccades.csv
# ['003', 'ES0001_S022_Script.txt']
# Analiysing session: ES0001_S022_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S022_PC_EM\01 Processing_data\pupil_labs\003\exports\000\annotations.csv, gaze: data\ES0001_S022_saccades.csv
# ['004', '20230419__ES0001_S023_Script.txt']
# Analiysing session: ES0001_S023_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S023_PC_EM\01 Processing_data\pupil_labs\004\exports\000\annotations.csv, gaze: data\ES0001_S023_saccades.csv
# ['000']
# Analiysing session: ES0001_S024_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S024_PC_EM\01 Processing_data\pupil_labs\000\exports\000\annotations.csv, gaze: data\ES0001_S024_saccades.csv
# ['002', 'ES001_S0025_Script_Check.txt']
# Analiysing session: ES0001_S025_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S025_PC_EM\01 Processing_data\pupil_labs\002\exports\000\annotations.csv, gaze: data\ES0001_S025_saccades.csv
# ['004']
# Analiysing session: ES0001_S026_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S026_PC_EM\01 Processing_data\pupil_labs\004\exports\001\annotations.csv, gaze: data\ES0001_S026_saccades.csv
# ['001', 'ES001_S027_Script.txt']
# Analiysing session: ES0001_S027_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S027_PC_EM\01 Processing_data\pupil_labs\001\exports\000\annotations.csv, gaze: data\ES0001_S027_saccades.csv
# ['002', 'ES0001_S028_Script.txt']
# Analiysing session: ES0001_S028_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S028_PC_EM\01 Processing_data\pupil_labs\002\exports\000\annotations.csv, gaze: data\ES0001_S028_saccades.csv
# ['004', 'ES001_S029_Script.txt']
# Analiysing session: ES0001_S029_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S029_PC_EM\01 Processing_data\pupil_labs\004\exports\002\annotations.csv, gaze: data\ES0001_S029_saccades.csv
# ['005', 'ES001_S030_Script.txt']
# Analiysing session: ES0001_S030_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S030_PC_EM\01 Processing_data\pupil_labs\005\exports\000\annotations.csv, gaze: data\ES0001_S030_saccades.csv
# ['006', 'ES001_S031_Script.txt']
# Analiysing session: ES0001_S031_PC_EM, annotations: P:\Proyectos\2020\PY200016 - XSCAPE\Trabajo\00 XPERIMENTS\01 EXPERIMENTS_Santiago\00 COMPLETED\Exp_Stgo_0001\SESSIONS\ES0001_S031_PC_EM\01 Processing_data\pupil_labs\006\exports\000\annotations.csv, gaze: data\ES0001_S031_saccades.csv

# %%
type(annotations_csv)
# Out:
# str

# %%
recording_folder
# Out:
# ['006']

# %%
vertical_index_concat_df
# Out:
#                    Asset0001  Asset0002  Asset0003  Asset0004  Asset0005  \
# ES0001_S003_PC_EM   0.200000  -0.111111   0.120000  -0.200000   0.111111
# ES0001_S004_PC_EM   0.166667   0.153846   0.217391   0.625000   0.478261
# ES0001_S005_PC_EM   0.200000   0.238095   0.142857   0.076923   0.238095
# ES0001_S006_PC_EM   0.250000   0.052632   0.130435   0.100000   0.407407
# ES0001_S008_PC_EM   0.000000   0.478261   0.090909   0.238095   0.217391
# ES0001_S009_PC_EM  -0.100000   0.000000   0.500000   0.294118   0.444444
# ES0001_S010_PC_EM   0.238095  -0.333333  -0.090909   0.238095  -0.090909
# ES0001_S011_PC_EM   0.083333   0.263158   0.181818   0.333333   0.300000
# ES0001_S012_PC_EM   0.217391  -0.052632   0.157895   0.047619   0.217391
# ES0001_S013_PC_EM   0.040000  -0.142857   0.000000   0.250000   0.363636
# ES0001_S015_PC_EM   0.200000   0.238095   0.142857   0.076923   0.238095
# ES0001_S017_PC_EM   0.043478   0.000000   0.222222  -0.300000  -0.100000
# ES0001_S018_PC_EM   0.166667   0.200000   0.304348   0.454545   0.428571
# ES0001_S019_PC_EM   0.047619   0.272727   0.043478   0.304348   0.363636
# ES0001_S020_PC_EM  -0.181818  -0.083333   0.461538  -0.125000   0.217391
# ES0001_S022_PC_EM   0.047619   0.407407   0.250000   0.217391   0.043478
# ES0001_S023_PC_EM  -0.052632  -0.047619   0.272727   0.090909  -0.333333
# ES0001_S024_PC_EM  -0.100000   0.217391  -0.142857   0.444444   0.052632
# ES0001_S025_PC_EM  -0.083333  -0.040000   0.290323  -0.250000   0.545455
# ES0001_S026_PC_EM   0.043478   0.565217   0.538462   0.130435   0.040000
# ES0001_S027_PC_EM  -0.043478   0.272727   0.000000   0.181818   0.391304
# ES0001_S028_PC_EM   0.304348  -0.083333   0.333333   0.448276  -0.300000
# ES0001_S029_PC_EM   0.363636  -0.111111   0.473684   0.272727   0.466667
# ES0001_S030_PC_EM  -0.333333   0.263158   0.520000   0.363636  -0.238095
# ES0001_S031_PC_EM   0.090909   0.619048   0.333333   0.636364  -0.047619
#
#                    Asset0006  Asset0007  Asset0008  Asset0009  Asset0010  ...  \
# ES0001_S003_PC_EM  -0.263158   0.111111   0.238095   0.125000   0.157895  ...
# ES0001_S004_PC_EM   0.333333   0.444444   0.904762   0.000000   0.166667  ...
# ES0001_S005_PC_EM   0.181818  -0.066667   0.529412   0.578947  -0.473684  ...
# ES0001_S006_PC_EM   0.250000   0.181818   0.333333   0.600000  -0.047619  ...
# ES0001_S008_PC_EM   0.333333   0.384615   0.391304  -0.166667   0.440000  ...
# ES0001_S029_PC_EM   0.700000    0.300000   -0.142857    0.333333    0.473684
# ES0001_S030_PC_EM   0.375000    0.714286    0.272727    0.200000    0.520000
# ES0001_S031_PC_EM   0.333333    0.692308    0.130435    0.176471    0.545455
#
# [25 rows x 54 columns]

# %%
# %matplotlib inline

vi=pd.read_csv('vi_table.csv')
vi_df=vi.reindex(vi.columns[vi.columns.str.contains('Asset')],axis=1)
vi_df.boxplot()
# Out:
# <AxesSubplot: >

# %%
import seaborn as sns
sns.set_theme(style='darkgrid')
ax, fig=plt.subplots(1,)
sns.boxplot(data=vi_df)
# Out:
# <AxesSubplot: >

# %%
sns.set_theme(style='darkgrid')
ax, fig=plt.subplots(1,)
sns.lineplot(data=np.mean(vi_df))
# Out:
# c:\Users\arturoV\AppData\Local\miniconda3\envs\analysis\Lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# <AxesSubplot: >

# %% [markdown]
# ### Adding chrono tables

# %%
chrono_df= (pd.read_csv('chrono.csv',delimiter=';',usecols=['Chrono_ID','Begin_date','End_date'])
            .assign(final_date= lambda x: (x.Begin_date+x.End_date)/2))
chrono_df.head()
# Out:
#     Chrono_ID  Begin_date  End_date  final_date
# 0  Chrono0001       -5500     -5000     -5250.0
# 1  Chrono0002       -5000     -4400     -4700.0
# 2  Chrono0003       -4400     -3500     -3950.0
# 3  Chrono0004       -3500     -2800     -3150.0
# 4  Chrono0005       -2800     -2200     -2500.0

# %%
asset_df=pd.read_csv('asset.csv',delimiter=';',usecols=['Asset_ID','Chrono_ID']).merge(chrono_df,on='Chrono_ID')
asset_df.head()
# Out:
#     Asset_ID   Chrono_ID  Begin_date  End_date  final_date
# 0  Asset0001  Chrono0019       -5500     -5250     -5375.0
# 1  Asset0002  Chrono0020       -5250     -4950     -5100.0
# 2  Asset0003  Chrono0020       -5250     -4950     -5100.0
# 3  Asset0004  Chrono0020       -5250     -4950     -5100.0
# 4  Asset0005  Chrono0021       -5000     -4600     -4800.0

# %%
vi_df_med=vi_df.median(axis=0).to_frame().reset_index()
vi_df_med.columns=['Asset_ID','vi']
vi_df_med.head()
# Out:
#     Asset_ID        vi
# 0  Asset0001  0.047619
# 1  Asset0002  0.153846
# 2  Asset0003  0.217391
# 3  Asset0004  0.238095
# 4  Asset0005  0.217391

# %%
asset_time_df=(vi_df_med.merge(asset_df,on='Asset_ID')
               .sort_values(by='final_date',ascending=True)
               #.query('final_date<-3000')
               )

# %%
asset_time_df
# Out:
#      Asset_ID        vi   Chrono_ID  Begin_date  End_date  final_date
# 0   Asset0001  0.047619  Chrono0019       -5500     -5250     -5375.0
# 1   Asset0002  0.153846  Chrono0020       -5250     -4950     -5100.0
# 2   Asset0003  0.217391  Chrono0020       -5250     -4950     -5100.0
# 3   Asset0004  0.238095  Chrono0020       -5250     -4950     -5100.0
# 4   Asset0005  0.217391  Chrono0021       -5000     -4600     -4800.0
# 5   Asset0006  0.125000  Chrono0022       -4600     -4450     -4525.0
# 6   Asset0007  0.272727  Chrono0023       -4450     -4000     -4225.0
# 7   Asset0008  0.391304  Chrono0023       -4450     -4000     -4225.0
# 8   Asset0009  0.300000  Chrono0025       -4000     -3500     -3750.0
# 9   Asset0010  0.000000  Chrono0025       -4000     -3500     -3750.0
# 40  Asset0046  0.047619  Chrono0052       -4500     -2700     -3600.0
# 11  Asset0012  0.238095  Chrono0027       -3500     -3100     -3300.0
# 10  Asset0011  0.304348  Chrono0028       -3400     -3100     -3250.0
# 12  Asset0014  0.280000  Chrono0051       -3300     -2800     -3050.0
# 13  Asset0015  0.222222  Chrono0029       -3300     -2800     -3050.0
# 14  Asset0016  0.238095  Chrono0029       -3300     -2800     -3050.0
# 15  Asset0017  0.473684  Chrono0051       -3300     -2800     -3050.0
# 16  Asset0018  0.473684  Chrono0030       -3000     -2800     -2900.0
# 17  Asset0020  0.440000  Chrono0030       -3000     -2800     -2900.0
# 18  Asset0021  0.363636  Chrono0031       -2800     -2500     -2650.0
# 19  Asset0022 -0.400000  Chrono0034       -2800     -2200     -2500.0
# 42  Asset0048  0.294118  Chrono0053       -2700     -2300     -2500.0
# 21  Asset0026  0.083333  Chrono0034       -2800     -2200     -2500.0
# 24  Asset0029  0.111111  Chrono0035       -2500     -2200     -2350.0
# 22  Asset0027  0.217391  Chrono0035       -2500     -2200     -2350.0
# 23  Asset0028  0.368421  Chrono0032       -2500     -2050     -2275.0
# 20  Asset0024  0.428571  Chrono0032       -2500     -2050     -2275.0
# 41  Asset0047  0.043478  Chrono0056       -2300     -1800     -2050.0
# 25  Asset0030  0.333333  Chrono0036       -2300     -1600     -1950.0
# 26  Asset0031  0.157895  Chrono0036       -2300     -1600     -1950.0
# 27  Asset0032  0.400000  Chrono0038       -1300      -750     -1025.0
# 28  Asset0033  0.222222  Chrono0041       -1300      -750     -1025.0
# 29  Asset0034  0.304348  Chrono0045       -1300      -750     -1025.0
# 30  Asset0035  0.181818  Chrono0046       -1300      -750     -1025.0
# 31  Asset0036 -0.076923  Chrono0038       -1300      -750     -1025.0
# 32  Asset0037  0.473684  Chrono0041       -1300      -750     -1025.0
# 33  Asset0039  0.333333  Chrono0042        -750      -500      -625.0
# 34  Asset0040  0.333333  Chrono0047        -750      -450      -600.0
# 43  Asset0049  0.181818  Chrono0057        -400      -200      -300.0
# 44  Asset0050  0.333333  Chrono0057        -400      -200      -300.0
# 36  Asset0042  0.428571  Chrono0044        -500       -60      -280.0
# 35  Asset0041  0.166667  Chrono0044        -500       -60      -280.0
# 37  Asset0043  0.157895  Chrono0048        -300       -60      -180.0
# 38  Asset0044  0.125000  Chrono0049        -200        85       -57.5
# 39  Asset0045  0.333333  Chrono0050        -150        60       -45.0

# %%
fig,ax=plt.subplots(1,)
ax.plot(asset_time_df['final_date'],asset_time_df['vi'],'-o')
fig.tight_layout()
